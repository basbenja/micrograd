# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

sys.path.append(os.path.dirname(os.getcwd()))

from nn import MLP

# %% [markdown]
# Para poder aplicar el descenso por el gradiente sobre los parámetros de la red, necesitamos primero juntar los parámetros.
#
# Para hacerlo, agregamos el método `parameters` a las clases `Neuron`, `Layer` y `MLP`.

# %%
nn = MLP(3, [4, 4, 1])
x = [2.0, 3.0, -1.0]
nn(x)

# %%
for p in nn.parameters():
    print(p)
print(f"\nAmount of parameters: {len(nn.parameters())}")
